# %% [markdown]
# ## SMS Spam Classifier: Multinomial Naive Bayes
#
# The notebook is divided into the following sections:
# 1. Importing and preprocessing data
# 2. Building the model: Multinomial Naive Bayes
#     - Model building
#     - Model evaluation

# %% [markdown]
# ### 1. Importing and Preprocessing Data

# %%
import pandas as pd

# reading the training data

docs = pd.read_csv('smsspamcollection.csv', header=None, names=['Class', 'sms'])
docs.head()
# Out:
#   Class                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# number of SMSes / documents
len(docs)
# Out:
# 5572

# %%
# counting spam and ham instances
ham_spam = docs.Class.value_counts()
ham_spam
# Out:
# ham     4825
# spam     747
# Name: Class, dtype: int64

# %%
print("spam rate is about {0}%".format(
    round((ham_spam[1]/float(ham_spam[0]+ham_spam[1]))*100), 2))
# Out:
# spam rate is about 13%

# %%
# mapping labels to 0 and 1
docs['label'] = docs.Class.map({'ham':0, 'spam':1})

# %%
docs.head()
# Out:
#   Class                                                sms  label
# 0   ham  Go until jurong point, crazy.. Available only ...      0
# 1   ham                      Ok lar... Joking wif u oni...      0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3   ham  U dun say so early hor... U c already then say...      0
# 4   ham  Nah I don't think he goes to usf, he lives aro...      0

# %%
# we can now drop the column 'Class'
docs = docs.drop('Class', axis=1)
docs.head()
# Out:
#                                                  sms  label
# 0  Go until jurong point, crazy.. Available only ...      0
# 1                      Ok lar... Joking wif u oni...      0
# 2  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3  U dun say so early hor... U c already then say...      0
# 4  Nah I don't think he goes to usf, he lives aro...      0

# %%
# convert to X and y
X = docs.sms
y = docs.label
print(X.shape)
print(y.shape)
# Out:
# (5572,)
# (5572,)

# %%
# splitting into test and train
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
# 710     4mths half price Orange line rental & latest c...
# 3740                           Did you stitch his trouser
# 2711    Hope you enjoyed your new content. text stop t...
# 3155    Not heard from U4 a while. Call 4 rude chat pr...
# 3748    Ü neva tell me how i noe... I'm not at home in...
# Name: sms, dtype: object

# %%
y_train.head()
# Out:
# 710     1
# 3740    0
# 2711    1
# 3155    1
# 3748    0
# Name: label, dtype: int64

# %%
# vectorizing the sentences; removing stop words
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words='english')

# %%
vect.fit(X_train)
# Out:
# CountVectorizer(stop_words='english')

# %%
# printing the vocabulary
vect.vocabulary_
# Out:
# {'4mths': 509,
#  'half': 3089,
#  'price': 5027,
#  'orange': 4626,
#  'line': 3852,
#  'rental': 5310,
#  'latest': 3763,
#  'camera': 1527,
#  'phones': 4822,
#  'free': 2780,
#  'phone': 4818,
#  '11mths': 264,
#  'mobilesdirect': 4248,
#  '08000938767': 50,
#  'update': 6674,
#  'or2stoptxt': 4624,
#  'cs': 1971,
#  'did': 2169,
#  'stitch': 6028,
#  'trouser': 6545,
#  'hope': 3260,
#  'enjoyed': 2436,
#  'new': 4442,
#  'content': 1867,
#  'text': 6321,
#  'stop': 6038,
#  '61610': 563,
#  'unsubscribe': 6666,
#  'help': 3180,
#  '08712400602450p': 98,
#  'provided': 5089,
#  'tones2you': 6473,
#  'uk': 6615,
#  'heard': 3159,
#  'u4': 6608,
#  'rude': 5443,
#  'chat': 1643,
#  'private': 5040,
#  '01223585334': 5,
#  'cum': 1989,
#  'wan': 6853,
#  '2c': 374,
#  'pics': 4837,
#  'gettin': 2913,
#  'shagged': 5628,
#  'pix': 4858,
#  '8552': 660,
#  '2end': 378,
#  'send': 5590,
#  'sam': 5487,
#  'xxx': 7128,
#  'neva': 4438,
#  'tell': 6289,
#  'noe': 4477,
#  'home': 3244,
#  'da': 2015,
#  'aft': 826,
#  'wat': 6877,
#  'wiskey': 7013,
#  'brandy': 1389,
#  'rum': 5450,
#  'gin': 2927,
#  'beer': 1209,
#  'vodka': 6799,
#  'scotch': 5535,
#  'shampain': 5637,
#  'wine': 6994,
#  'kudi': 3715,
#  'yarasu': 7143,
#  'dhina': 2156,
#  'vaazhthukkal': 6721,
#  'seeking': 5573,
#  'lady': 3732,
#  'street': 6056,
#  'freak': 2776,
#  'sheets': 5649,
#  'lol': 3910,
#  'drunkard': 2327,
#  'just': 3623,
#  'doing': 2259,
#  'hair': 3085,
#  'moment': 4265,
#  'yeah': 7150,
#  'tonight': 6475,
#  'wats': 6888,
#  'plan': 4867,
#  'turning': 6579,
#  'moms': 4267,
#  'telling': 6290,
#  'cancer': 1535,
#  'sister': 5745,
#  'won': 7042,
#  'calling': 1519,
#  'hurts': 3323,
#  'talk': 6234,
#  'love': 3953,
#  'coming': 1800,
#  'dinner': 2193,
#  'rite': 5396,
#  'dad': 2018,
#  'ask': 1032,
#  'confirm': 1843,
#  'wif': 6978,
#  'ah': 842,
#  'poor': 4931,
#  'baby': 1121,
#  'urfeeling': 6688,
#  'bettersn': 1243,
#  'luv': 3988,
#  'probthat': 5052,
#  'overdose': 4667,
#  'work': 7059,
#  'hey': 3198,
#  'careful': 1556,
#  'spk': 5938,
#  'sn': 5822,
#  'lots': 3942,
#  'lovejen': 3955,
#  'gam': 2856,
#  'gone': 2968,
#  'outstanding': 4664,
#  'innings': 3438,
#  'nice': 4453,
#  'working': 7063,
#  'haha': 3081,
#  'kidding': 3672,
#  'papa': 4705,
#  'needs': 4417,
#  'drugs': 2325,
#  'chief': 1677,
#  'bell': 1223,
#  'need': 4412,
#  'royal': 5432,
#  'visit': 6790,
#  '1st': 324,
#  'june': 3618,
#  'ugh': 6611,
#  'long': 3917,
#  'day': 2054,
#  'exhausted': 2523,
#  'want': 6858,
#  'cuddle': 1984,
#  'nap': 4381,
#  'awesome': 1103,
#  'time': 6418,
#  'like': 3840,
#  'lt': 3974,
#  'gt': 3044,
#  'll': 3887,
#  'details': 2143,
#  'wee': 6917,
#  'bit': 1277,
#  'ok': 4578,
#  'lor': 3932,
#  'thk': 6376,
#  'tickets': 6407,
#  'cos': 1901,
#  'quite': 5149,
#  'late': 3760,
#  'look': 3921,
#  'ur': 6685,
#  'frens': 2791,
#  'darren': 2041,
#  'dont': 2269,
#  'know': 3700,
#  'bring': 1414,
#  'food': 2730,
#  'reason': 5224,
#  've': 6745,
#  'spoken': 5948,
#  'year': 7151,
#  'anyways': 947,
#  'great': 3020,
#  'week': 6919,
#  'best': 1237,
#  'exam': 2511,
#  'make': 4042,
#  'fucks': 2825,
#  'sake': 5476,
#  'yes': 7161,
#  'place': 4862,
#  'town': 6504,
#  'meet': 4130,
#  'exciting': 2515,
#  'adult': 806,
#  'singles': 5739,
#  'txt': 6590,
#  '86688': 664,
#  '150p': 293,
#  'msg': 4315,
#  'man': 4052,
#  'print': 5035,
#  'outs': 4660,
#  'room': 5418,
#  'think': 6368,
#  'saying': 5517,
#  'clearly': 1734,
#  'leave': 3793,
#  'come': 1794,
#  'st': 5972,
#  'andre': 912,
#  'virgil': 6784,
#  'cream': 1947,
#  'yoyyooo': 7180,
#  'change': 1623,
#  'permissions': 4789,
#  'drive': 2313,
#  'mac': 4013,
#  'usb': 6700,
#  'flash': 2692,
#  'sunshine': 6148,
#  'quiz': 5151,
#  'wkly': 7025,
#  'win': 6988,
#  'sony': 5865,
#  'dvd': 2350,
#  'player': 4875,
#  'country': 1914,
#  'algarve': 875,
#  'ansr': 927,
#  '82277': 637,
#  '50': 520,
#  'sp': 5898,
#  'tyrone': 6606,
#  'dear': 2066,
#  'th': 6333,
#  'birthday': 1275,
#  'loving': 3963,
#  'gopalettan': 2984,
#  'planning': 4871,
#  'small': 5796,
#  'gift': 2921,
#  'participate': 4724,
#  'welcome': 6934,
#  'contact': 1863,
#  'admin': 793,
#  'team': 6274,
#  'class': 1724,
#  'hours': 3282,
#  'sorry': 5877,
#  'okay': 4579,
#  'wait': 6835,
#  'rushing': 5458,
#  'school': 5527,
#  'rush': 5457,
#  'hungry': 3314,
#  'usually': 6713,
#  'stops': 6044,
#  'hella': 3177,
#  'weed': 6918,
#  'smoke': 5811,
#  'awarded': 1101,
#  'city': 1715,
#  'break': 1396,
#  '200': 335,
#  'summer': 6139,
#  'shopping': 5681,
#  'spree': 5961,
#  'wk': 7021,
#  'store': 6046,
#  '88039': 675,
#  'skilgme': 5759,
#  'tscs087147403231winawk': 6562,
#  'age16': 832,
#  '50perwksub': 528,
#  'shall': 5635,
#  'pickle': 4836,
#  'isn': 3506,
#  'frnd': 2809,
#  'necesity': 4407,
#  'life': 3830,
#  'imagine': 3376,
#  'urself': 6698,
#  'witout': 7018,
#  'hw': 3328,
#  'feel': 2620,
#  'colleg': 1786,
#  'wth': 7103,
#  'cell': 1605,
#  'abt': 742,
#  'functions': 2833,
#  'thnk': 6378,
#  'events': 2491,
#  'espe': 2474,
#  'cared': 1553,
#  'missed': 4215,
#  'amp': 903,
#  'irritated': 3496,
#  '4wrd': 517,
#  'frnds': 2810,
#  'wthout': 7104,
#  'live': 3880,
#  'jst': 3605,
#  'takecare': 6228,
#  'goodmorning': 2977,
#  'brum': 1437,
#  'thanks': 6337,
#  'putting': 5126,
#  'keeping': 3651,
#  'happy': 3120,
#  'soon': 5868,
#  'im': 3373,
#  'tellmiss': 6291,
#  'way': 6892,
#  'bloomberg': 1310,
#  'message': 4163,
#  'center': 1607,
#  '447797706009': 482,
#  'apply': 969,
#  'future': 2842,
#  'http': 3298,
#  'careers': 1555,
#  'com': 1791,
#  'enjoy': 2435,
#  'plural': 4892,
#  'noun': 4515,
#  'research': 5331,
#  'sure': 6165,
#  'checking': 1656,
#  'happening': 3114,
#  'area': 991,
#  'aight': 850,
#  'sleeping': 5774,
#  'surfing': 6168,
#  'cool': 1888,
#  'breeze': 1406,
#  'bright': 1410,
#  'sun': 6142,
#  'fresh': 2793,
#  'flower': 2711,
#  'twittering': 6588,
#  'birds': 1270,
#  'waiting': 6838,
#  'wish': 7007,
#  'ringtone': 5389,
#  'order': 4630,
#  'reference': 5261,
#  'number': 4526,
#  'x49': 7115,
#  'mobile': 4246,
#  'charged': 1633,
#  'tone': 6470,
#  'arrive': 1016,
#  'customer': 2002,
#  'services': 5609,
#  '09065989182': 214,
#  'colour': 1789,
#  'red': 5257,
#  'txtstar': 6598,
#  'does': 2245,
#  'uncle': 6627,
#  'timi': 6420,
#  'clearing': 1733,
#  'cars': 1569,
#  'getting': 2914,
#  'really': 5219,
#  'bad': 1128,
#  'totally': 6498,
#  'rejected': 5281,
#  'kinda': 3682,
#  'thing': 6366,
#  'sent': 5598,
#  'prices': 5028,
#  'mean': 4116,
#  'hi': 3202,
#  'darlin': 2038,
#  'london': 3914,
#  'smashed': 5801,
#  'driver': 2314,
#  'big': 1257,
#  'dent': 2118,
#  'missing': 4217,
#  'took': 6479,
#  'tablets': 6217,
#  'reaction': 5205,
#  'morning': 4289,
#  'going': 2959,
#  'intention': 3459,
#  'run': 5453,
#  'choose': 1700,
#  'clean': 1728,
#  'don': 2266,
#  'say': 5516,
#  'visitors': 6792,
#  'maybe': 4111,
#  'choice': 1698,
#  'wanted': 6860,
#  'embarassed': 2413,
#  'friend': 2800,
#  'wants': 6862,
#  'drop': 2319,
#  'buy': 1483,
#  'happened': 3113,
#  'tried': 6537,
#  'picking': 4835,
#  'various': 6736,
#  'points': 4914,
#  'yeovil': 7158,
#  'motor': 4298,
#  'project': 5064,
#  '12': 266,
#  '30': 412,
#  'max': 4106,
#  'easy': 2368,
#  'test': 6316,
#  'rd': 5199,
#  'fret': 2794,
#  'ovulation': 4673,
#  'strips': 6066,
#  'wont': 7049,
#  'til': 6416,
#  'march': 4072,
#  'postal': 4953,
#  'address': 790,
#  'alright': 887,
#  'loyalty': 3970,
#  'offer': 4560,
#  'nokia6650': 4485,
#  '10': 244,
#  'txtauction': 6593,
#  'word': 7057,
#  'start': 5993,
#  '81151': 632,
#  '4t': 511,
#  'ctxt': 1982,
#  'tc': 6266,
#  'mtmsg': 4325,
#  'remember': 5295,
#  'alex': 873,
#  'pizza': 4860,
#  'av': 1084,
#  'wil': 6983,
#  'use': 6702,
#  'ta': 6214,
#  'urgent': 6689,
#  'trying': 6558,
#  'todays': 6454,
#  'draw': 2301,
#  'shows': 5701,
#  '800': 617,
#  'prize': 5043,
#  'guaranteed': 3048,
#  '09050001808': 158,
#  'land': 3740,
#  'claim': 1718,
#  'm95': 4008,
#  'valid12hrs': 6728,
#  'babe': 1119,
#  'lost': 3939,
#  'painful': 4690,
#  'personal': 4795,
#  'thought': 6384,
#  'try': 6556,
#  'everybody': 2492,
#  'recognises': 5250,
#  'subscribed': 6105,
#  'service': 5608,
#  'days': 2055,
#  '82324': 638,
#  'helpline': 3185,
#  '08706091795': 83,
#  'basket': 1164,
#  'mum': 4336,
#  'messages': 4165,
#  'got': 2988,
#  'actually': 781,
#  'rest': 5351,
#  'january': 3541,
#  'male': 4049,
#  'sale': 5480,
#  'hot': 3276,
#  'gay': 2877,
#  'cheaper': 1649,
#  '08709222922': 88,
#  'national': 4391,
#  'rate': 5187,
#  '5p': 548,
#  'min': 4187,
#  'cheap': 1648,
#  '8p': 695,
#  'peak': 4765,
#  'texts': 6331,
#  '08712460324': 108,
#  '10p': 254,
#  'honesty': 3249,
#  'road': 5399,
#  'bank': 1146,
#  'tomorrow': 6469,
#  'tough': 6502,
#  'decisions': 2080,
#  'people': 4776,
#  'womdarfull': 7040,
#  'actor': 779,
#  'congrats': 1847,
#  'special': 5910,
#  'cinema': 1713,
#  'pass': 4731,
#  '09061209465': 180,
#  'suprman': 6163,
#  'matrix3': 4101,
#  'starwars3': 5997,
#  'bx420': 1493,
#  'ip4': 3484,
#  '5we': 552,
#  '150pm': 295,
#  'miss': 4213,
#  'movie': 4304,
#  'juz': 3626,
#  'minute': 4202,
#  'decision': 2079,
#  'mah': 4031,
#  'watch': 6878,
#  'lar': 3751,
#  'tot': 6496,
#  'interested': 3460,
#  'care': 1551,
#  'sweet': 6191,
#  'dreams': 2305,
#  'ummifying': 6621,
#  'bye': 1495,
#  'gud': 3050,
#  'ni8': 4451,
#  'slp': 5794,
#  'swt': 6203,
#  'muah': 4330,
#  'youdoing': 7173,
#  'later': 3762,
#  'sar': 5495,
#  'money': 4270,
#  '09050000460': 153,
#  'j89': 3526,
#  'po': 4897,
#  'box245c2150pm': 1364,
#  'issue': 3508,
#  'weigh': 6925,
#  'breathe': 1403,
#  'easier': 2363,
#  'regret': 5278,
#  'gr8': 3000,
#  'leaving': 3795,
#  'plans': 4872,
#  'havent': 3142,
#  'sir': 5742,
#  'group': 3034,
#  'mail': 4034,
#  'check': 1653,
#  'hit': 3216,
#  'cash': 1573,
#  'girl': 2928,
#  '2004': 338,
#  'account': 760,
#  'statement': 5998,
#  '07742676969': 27,
#  '786': 608,
#  'unredeemed': 6662,
#  'bonus': 1332,
#  '08719180248': 144,
#  'identifier': 3355,
#  'code': 1770,
#  '45239': 489,
#  'expires': 2538,
#  'mins': 4200,
#  'busy': 1479,
#  'finish': 2670,
#  'looking': 3924,
#  'forward': 2761,
#  'finally': 2663,
#  'meeting': 4132,
#  'hmv': 3230,
#  '500': 521,
#  'pounds': 4965,
#  'genuine': 2901,
#  'vouchers': 6809,
#  'answer': 928,
#  'questions': 5144,
#  'play': 4873,
#  'info': 3425,
#  'www': 7111,
#  '100percent': 249,
#  'real': 5210,
#  'accidentally': 754,
#  'left': 3798,
#  'silent': 5726,
#  'night': 4460,
#  'didn': 2170,
#  'ya': 7135,
#  'tht': 6398,
#  'incident': 3399,
#  'good': 2972,
#  'problem': 5047,
#  'little': 3879,
#  'experience': 2534,
#  'understand': 6634,
#  'american': 895,
#  'voice': 6800,
#  'used': 6703,
#  'agents': 836,
#  'booked': 1336,
#  'things': 6367,
#  'boston': 1350,
#  'nyc': 4539,
#  'experiment': 2535,
#  'online': 4599,
#  'transaction': 6515,
#  'came': 1526,
#  'hostel': 3274,
#  'sleep': 5772,
#  'plz': 4895,
#  'hrishi': 3295,
#  'fuuuuck': 2843,
#  'sleepin': 5773,
#  'sup': 6150,
#  'dude': 2337,
#  'makin': 4045,
#  'weirdy': 6932,
#  'brownies': 1433,
#  'cookies': 1886,
#  'secret': 5560,
#  'admirer': 795,
#  'reveal': 5368,
#  'thinks': 6372,
#  '09058094599': 175,
#  'oh': 4573,
#  'training': 6512,
#  'manual': 4066,
#  'tech': 6279,
#  'process': 5053,
#  'password': 4737,
#  'reset': 5337,
#  'troubleshooting': 6544,
#  'computerless': 1831,
#  'oreo': 4633,
#  'truffles': 6550,
#  'watching': 6881,
#  'tv': 6582,
#  'job': 3580,
#  'hoping': 3264,
#  'game': 2858,
#  'yesterday': 7163,
#  'touch': 6500,
#  'pls': 4888,
#  'fondly': 2725,
#  'bein': 1220,
#  'thot': 6382,
#  'abiola': 732,
#  'nite': 4470,
#  'pocay': 4907,
#  'wocay': 7036,
#  '4eva': 502,
#  'promise': 5068,
#  'ring': 5387,
#  '2morrowxxxx': 393,
#  'yup': 7190,
#  'thanx': 6342,
#  'reply': 5321,
#  'pick': 4833,
#  'heart': 3162,
#  'mind': 4190,
#  'wisdom': 7005,
#  'eyes': 2555,
#  'alwys': 891,
#  'panren': 4700,
#  'paru': 4729,
#  'wife': 6979,
#  'relax': 5286,
#  'wkend': 7022,
#  'fun': 2831,
#  'truly': 6551,
#  'forget': 2746,
#  'gbp': 2881,
#  'sms': 5817,
#  'approve': 975,
#  'panalam': 4695,
#  'posts': 4959,
#  'paid': 4688,
#  'commercial': 1804,
#  'hasbro': 3129,
#  'august': 1075,
#  'jump': 3616,
#  'hoops': 3258,
#  'shut': 5711,
#  'omg': 4592,
#  'dream': 2304,
#  'kids': 3673,
#  'boys': 1381,
#  'pissed': 4855,
#  'told': 6460,
#  'mark': 4076,
#  'changing': 1626,
#  'diapers': 2164,
#  'cause': 1588,
#  'owed': 4676,
#  'face': 2559,
#  'ey': 2553,
#  'calm': 1523,
#  'downon': 2292,
#  'theacusations': 6347,
#  'itxt': 3517,
#  'iwana': 3520,
#  'wotu': 7078,
#  'doin': 2257,
#  'thew': 6362,
#  'end': 2422,
#  'haventcn': 3143,
#  'ages': 837,
#  'up4': 6670,
#  'nething': 4432,
#  'sat': 5502,
#  'dramatic': 2299,
#  'schools': 5528,
#  'closed': 1742,
#  'apparently': 961,
#  'inch': 3397,
#  'snow': 5832,
#  'supposed': 6161,
#  'woke': 7037,
#  'blur': 1319,
#  'went': 6941,
#  'liao': 3821,
#  'oso': 4645,
#  'helloooo': 3179,
#  'wake': 6839,
#  'welcomes': 6935,
#  'joy': 3600,
#  'mrng': 4312,
#  'jason': 3546,
#  'says': 5518,
#  'gonna': 2970,
#  'mallika': 4051,
#  'sherawat': 5652,
#  'url': 6695,
#  'wa': 6824,
#  'openin': 4608,
#  'sentence': 5599,
#  'formal': 2753,
#  'fine': 2667,
#  'tt': 6565,
#  'eatin': 2371,
#  'puttin': 5125,
#  'weight': 6927,
#  'anythin': 944,
#  'tyler': 6602,
#  'minor': 4199,
#  'crisis': 1960,
#  'sooner': 5869,
#  'asap': 1024,
#  'erm': 2460,
#  'ill': 3369,
#  '45pm': 490,
#  'park': 4720,
#  'treat': 6529,
#  'pending': 4773,
#  'respect': 5343,
#  'mother': 4293,
#  'mails': 4037,
#  'alrite': 888,
#  'hunny': 3316,
#  'wot': 7077,
#  '2nite': 398,
#  'didnt': 2171,
#  'goin': 2958,
#  'jus': 3622,
#  'pub': 5101,
#  'instead': 3453,
#  'chillin': 1686,
#  'mo': 4242,
#  'bedroom': 1206,
#  'jen': 3559,
#  'aiyo': 860,
#  'meh': 4137,
#  'princess': 5034,
#  'times': 6419,
#  'thats': 6346,
#  'ew': 2507,
#  'friendship': 2803,
#  'poem': 4911,
#  'near': 4405,
#  'hear': 3158,
#  'fear': 2613,
#  'cheer': 1660,
#  'tear': 6275,
#  'added': 786,
#  'list': 3868,
#  'fullonsms': 2829,
#  'ignoring': 3363,
#  'dating': 2049,
#  'started': 5994,
#  'sport': 5954,
#  'radio': 5160,
#  'connection': 1851,
#  'coincidence': 1774,
#  'hook': 3257,
#  'means': 4120,
#  'right': 5383,
#  'valuable': 6729,
#  'situations': 5752,
#  'second': 5557,
#  'loosing': 3930,
#  'si': 5713,
#  'como': 1808,
#  'listened2the': 3871,
#  'plaid': 4866,
#  'album': 867,
#  'gd': 2884,
#  'air1': 854,
#  'hilarious': 3207,
#  'bought': 1354,
#  'braindance': 1386,
#  'comp': 1809,
#  'ofstuff': 4570,
#  'aphex': 953,
#  'abel': 728,
#  'hav2hear': 3139,
#  'xxxx': 7130,
#  'wana': 6855,
#  'praps': 4988,
#  'meant': 4121,
#  'goodo': 2981,
#  'stay': 6001,
#  'england': 2433,
#  'official': 4566,
#  'poly': 4918,
#  'flag': 2688,
#  'yer': 7160,
#  '84199': 653,
#  'opt': 4618,
#  'eng': 2430,
#  'box39822': 1369,
#  'w111wx': 6815,
#  'honeybee': 3251,
#  'said': 5475,
#  'sweetest': 6192,
#  'world': 7066,
#  'god': 2954,
#  'laughed': 3767,
#  'havnt': 3147,
#  'met': 4170,
#  'person': 4794,
#  'reading': 5208,
#  'moral': 4285,
#  'crack': 1934,
#  'jokes': 3590,
#  'gm': 2943,
#  'gn': 2945,
#  'ge': 2886,
#  'study': 6082,
#  'tap': 6247,
#  'spile': 5931,
#  'seven': 5616,
#  'gas': 2870,
#  'broad': 1422,
#  'canal': 1530,
#  'wan2': 6854,
#  'greet': 3023,
#  'westlife': 6951,
#  'm8': 4006,
#  'currently': 1997,
#  'tour': 6503,
#  'unbreakable': 6626,
#  'untamed': 6668,
#  'unkempt': 6653,
#  '83049': 640,
#  'cost': 1903,
#  '50p': 526,
#  'std': 6006,
#  'drunk': 2326,
#  'motherfucker': 4294,
#  'textbuddy': 6324,
#  'horny': 3266,
#  'guys': 3068,
#  '25p': 362,
#  'receive': 5237,
#  'search': 5552,
#  'postcode': 4955,
#  'gaytextbuddy': 2880,
#  '89693': 690,
#  '08715500022': 122,
#  'rpl': 5434,
#  'cnl': 1759,
#  'hiya': 3220,
#  'weekend': 6921,
#  'usual': 6712,
#  'ard': 990,
#  'smth': 5821,
#  'doc': 2239,
#  'gave': 2876,
#  'pain': 4689,
#  'meds': 4128,
#  'mahal': 4032,
#  'bus': 1473,
#  'decimal': 2078,
#  'cooking': 1887,
#  'oops': 4604,
#  'tomo': 6467,
#  'station': 5999,
#  'dhoni': 2157,
#  'luck': 3978,
#  'title': 6433,
#  'waking': 6840,
#  'afternoon': 828,
#  'church': 1710,
#  'holla': 3240,
#  'let': 3815,
#  'salad': 5477,
#  'desert': 2132,
#  'beers': 1210,
#  'news': 4447,
#  'freefone': 2784,
#  '08006344447': 56,
#  '1000': 246,
#  '2000': 336,
#  'speak': 5908,
#  'operator': 4612,
#  'hr': 3294,
#  'trip': 6538,
#  'audition': 1072,
#  'wednesday': 6915,
#  'whats': 6956,
#  'printed': 5036,
#  'upstairs': 6683,
#  'wasnt': 6873,
#  'phoned': 4821,
#  'voda': 6797,
#  'numbers': 4527,
#  'ending': 2424,
#  '1225': 270,
#  'selected': 5579,
#  '50award': 523,
#  'match': 4094,
#  '08712300220': 95,
#  'quoting': 5155,
#  '3100': 424,
#  'standard': 5984,
#  'rates': 5188,
#  'app': 960,
#  'today': 6453,
#  'accept': 749,
#  'brother': 1429,
#  'lover': 3958,
#  'dear1': 2067,
#  'best1': 1238,
#  'clos1': 1740,
#  'lvblefrnd': 3993,
#  'jstfrnd': 3606,
#  'cutefrnd': 2007,
#  'lifpartnr': 3833,
#  'belovd': 1228,
#  'swtheart': 6204,
#  'bstfrnd': 1442,
#  'rply': 5435,
#  'enemy': 2428,
#  'bloo': 1307,
#  'bowl': 1358,
#  'urgnt': 6692,
#  'wating': 6886,
#  'difficult': 2181,
#  'girls': 2931,
#  'companion': 1811,
#  'chef': 1666,
#  'listener': 3872,
#  'organizer': 4636,
#  'boyfriend': 1380,
#  'sympathetic': 6207,
#  'athletic': 1054,
#  'warm': 6865,
#  'courageous': 1919,
#  'determined': 2145,
#  'true': 6548,
#  'dependable': 2125,
#  'intelligent': 3457,
#  'psychologist': 5098,
#  'pest': 4802,
#  'exterminator': 2550,
#  'psychiatrist': 5096,
#  'healer': 3156,
#  'stylist': 6094,
#  'aaniye': 722,
#  'pudunga': 5105,
#  'venaam': 6750,
#  'request': 5326,
#  'maangalyam': 4011,
#  'alaipayuthe': 866,
#  'set': 5611,
#  'callertune': 1516,
#  'callers': 1515,
#  'press': 5017,
#  'copy': 1893,
#  'friends': 2801,
#  'tirunelvai': 6428,
#  'lick': 3825,
#  'pussy': 5123,
#  'inside': 3447,
#  'office': 4564,
#  'filling': 2654,
#  'forms': 2757,
#  'textin': 6327,
#  'bout': 1356,
#  'worries': 7070,
#  'photo': 4824,
#  'shoot': 5678,
#  ...}

# %%
# vocab size
len(vect.vocabulary_.keys())
# Out:
# 7204

# %%
(vect.vocabulary_.keys())
# Out:
# dict_keys(['4mths', 'half', 'price', 'orange', 'line', 'rental', 'latest', 'camera', 'phones', 'free', 'phone', '11mths', 'mobilesdirect', '08000938767', 'update', 'or2stoptxt', 'cs', 'did', 'stitch', 'trouser', 'hope', 'enjoyed', 'new', 'content', 'text', 'stop', '61610', 'unsubscribe', 'help', '08712400602450p', 'provided', 'tones2you', 'uk', 'heard', 'u4', 'rude', 'chat', 'private', '01223585334', 'cum', 'wan', '2c', 'pics', 'gettin', 'shagged', 'pix', '8552', '2end', 'send', 'sam', 'xxx', 'neva', 'tell', 'noe', 'home', 'da', 'aft', 'wat', 'wiskey', 'brandy', 'rum', 'gin', 'beer', 'vodka', 'scotch', 'shampain', 'wine', 'kudi', 'yarasu', 'dhina', 'vaazhthukkal', 'seeking', 'lady', 'street', 'freak', 'sheets', 'lol', 'drunkard', 'just', 'doing', 'hair', 'moment', 'yeah', 'tonight', 'wats', 'plan', 'turning', 'moms', 'telling', 'cancer', 'sister', 'won', 'calling', 'hurts', 'talk', 'love', 'coming', 'dinner', 'rite', 'dad', 'ask', 'confirm', 'wif', 'ah', 'poor', 'baby', 'urfeeling', 'bettersn', 'luv', 'probthat', 'overdose', 'work', 'hey', 'careful', 'spk', 'sn', 'lots', 'lovejen', 'gam', 'gone', 'outstanding', 'innings', 'nice', 'working', 'haha', 'kidding', 'papa', 'needs', 'drugs', 'chief', 'bell', 'need', 'royal', 'visit', '1st', 'june', 'ugh', 'long', 'day', 'exhausted', 'want', 'cuddle', 'nap', 'awesome', 'time', 'like', 'lt', 'gt', 'll', 'details', 'wee', 'bit', 'ok', 'lor', 'thk', 'tickets', 'cos', 'quite', 'late', 'look', 'ur', 'frens', 'darren', 'dont', 'know', 'bring', 'food', 'reason', 've', 'spoken', 'year', 'anyways', 'great', 'week', 'best', 'exam', 'make', 'fucks', 'sake', 'yes', 'place', 'town', 'meet', 'exciting', 'adult', 'singles', 'txt', '86688', '150p', 'msg', 'man', 'print', 'outs', 'room', 'think', 'saying', 'clearly', 'leave', 'come', 'st', 'andre', 'virgil', 'cream', 'yoyyooo', 'change', 'permissions', 'drive', 'mac', 'usb', 'flash', 'sunshine', 'quiz', 'wkly', 'win', 'sony', 'dvd', 'player', 'country', 'algarve', 'ansr', '82277', '50', 'sp', 'tyrone', 'dear', 'th', 'birthday', 'loving', 'gopalettan', 'planning', 'small', 'gift', 'participate', 'welcome', 'contact', 'admin', 'team', 'class', 'hours', 'sorry', 'okay', 'wait', 'rushing', 'school', 'rush', 'hungry', 'usually', 'stops', 'hella', 'weed', 'smoke', 'awarded', 'city', 'break', '200', 'summer', 'shopping', 'spree', 'wk', 'store', '88039', 'skilgme', 'tscs087147403231winawk', 'age16', '50perwksub', 'shall', 'pickle', 'isn', 'frnd', 'necesity', 'life', 'imagine', 'urself', 'witout', 'hw', 'feel', 'colleg', 'wth', 'cell', 'abt', 'functions', 'thnk', 'events', 'espe', 'cared', 'missed', 'amp', 'irritated', '4wrd', 'frnds', 'wthout', 'live', 'jst', 'takecare', 'goodmorning', 'brum', 'thanks', 'putting', 'keeping', 'happy', 'soon', 'im', 'tellmiss', 'way', 'bloomberg', 'message', 'center', '447797706009', 'apply', 'future', 'http', 'careers', 'com', 'enjoy', 'plural', 'noun', 'research', 'sure', 'checking', 'happening', 'area', 'aight', 'sleeping', 'surfing', 'cool', 'breeze', 'bright', 'sun', 'fresh', 'flower', 'twittering', 'birds', 'waiting', 'wish', 'ringtone', 'order', 'reference', 'number', 'x49', 'mobile', 'charged', 'tone', 'arrive', 'customer', 'services', '09065989182', 'colour', 'red', 'txtstar', 'does', 'uncle', 'timi', 'clearing', 'cars', 'getting', 'really', 'bad', 'totally', 'rejected', 'kinda', 'thing', 'sent', 'prices', 'mean', 'hi', 'darlin', 'london', 'smashed', 'driver', 'big', 'dent', 'missing', 'took', 'tablets', 'reaction', 'morning', 'going', 'intention', 'run', 'choose', 'clean', 'don', 'say', 'visitors', 'maybe', 'choice', 'wanted', 'embarassed', 'friend', 'wants', 'drop', 'buy', 'happened', 'tried', 'picking', 'various', 'points', 'yeovil', 'motor', 'project', '12', '30', 'max', 'easy', 'test', 'rd', 'fret', 'ovulation', 'strips', 'wont', 'til', 'march', 'postal', 'address', 'alright', 'loyalty', 'offer', 'nokia6650', '10', 'txtauction', 'word', 'start', '81151', '4t', 'ctxt', 'tc', 'mtmsg', 'remember', 'alex', 'pizza', 'a ...

# %%
# transforming the train and test datasets
X_train_transformed = vect.transform(X_train)
X_test_transformed = vect.transform(X_test)

# %%
# note that the type is transformed (sparse) matrix
print(type(X_train_transformed))
print(X_train_transformed)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 50)	1
#   (0, 264)	1
#   (0, 509)	1
#   (0, 1527)	1
#   (0, 1971)	1
#   (0, 2780)	2
#   (0, 3089)	1
#   (0, 3763)	1
#   (0, 3852)	1
#   (0, 4248)	1
#   (0, 4624)	1
#   (0, 4626)	1
#   (0, 4818)	1
#   (0, 4822)	1
#   (0, 5027)	1
#   (0, 5310)	1
#   (0, 6674)	1
#   (1, 2169)	1
#   (1, 6028)	1
#   (1, 6545)	1
#   (2, 98)	1
#   (2, 563)	1
#   (2, 1867)	1
#   (2, 2436)	1
#   (2, 3180)	1
#   :	:
#   (4176, 3879)	1
#   (4176, 4417)	1
#   (4176, 5229)	1
#   (4176, 6191)	1
#   (4176, 7135)	1
#   (4177, 254)	1
#   (4177, 307)	1
#   (4177, 358)	1
#   (4177, 831)	1
#   (4177, 2046)	1
#   (4177, 2704)	1
#   (4177, 3585)	1
#   (4177, 3623)	1
#   (4177, 4130)	1
#   (4177, 4315)	1
#   (4177, 4771)	1
#   (4177, 5234)	1
#   (4177, 5321)	1
#   (4177, 5487)	1
#   (4177, 5620)	1
#   (4177, 6321)	1
#   (4177, 6374)	1
#   (4177, 6453)	1
#   (4178, 1643)	1
#   (4178, 5817)	1

# %% [markdown]
# ### 2. Building and Evaluating the Model

# %%
# training the NB model and making predictions
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()

# fit
mnb.fit(X_train_transformed,y_train)

# predict class
y_pred_class = mnb.predict(X_test_transformed)

# predict probabilities
y_pred_proba = mnb.predict_proba(X_test_transformed)

# %%
# note that alpha=1 is used by default for smoothing
mnb
# Out:
# MultinomialNB()

# %% [markdown]
# ### Model Evaluation

# %%
# printing the overall accuracy
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.9877961234745154

# %%
# confusion matrix
metrics.confusion_matrix(y_test, y_pred_class)
# help(metrics.confusion_matrix)
# Out:
# array([[1201,    7],
#        [  10,  175]])

# %%
confusion = metrics.confusion_matrix(y_test, y_pred_class)
print(confusion)
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
TP = confusion[1, 1]
# Out:
# [[1201    7]
#  [  10  175]]

# %%
sensitivity = TP / float(FN + TP)
print("sensitivity",sensitivity)
# Out:
# sensitivity 0.9459459459459459

# %%
specificity = TN / float(TN + FP)
print("specificity",specificity)
# Out:
# specificity 0.9942052980132451

# %%
precision = TP / float(TP + FP)
print("precision",precision)
print(metrics.precision_score(y_test, y_pred_class))
# Out:
# precision 0.9615384615384616
# 0.9615384615384616

# %%
print("precision",precision)
print("PRECISION SCORE :",metrics.precision_score(y_test, y_pred_class))
print("RECALL SCORE :", metrics.recall_score(y_test, y_pred_class))
print("F1 SCORE :",metrics.f1_score(y_test, y_pred_class))
# Out:
# precision 0.9615384615384616
# PRECISION SCORE : 0.9615384615384616
# RECALL SCORE : 0.9459459459459459
# F1 SCORE : 0.9536784741144414

# %%
y_pred_class
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
y_pred_proba
# Out:
# array([[9.95239557e-01, 4.76044325e-03],
#        [9.99852357e-01, 1.47642544e-04],
#        [9.27878579e-01, 7.21214213e-02],
#        ...,
#        [9.99999671e-01, 3.28799076e-07],
#        [3.72703622e-09, 9.99999996e-01],
#        [9.99999985e-01, 1.46852511e-08]])

# %%
# creating an ROC curve
from sklearn.metrics import confusion_matrix as sk_confusion_matrix
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_proba[:,1])
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
# area under the curve
print (roc_auc)
# Out:
# 0.9921872203329157

# %%
# matrix of thresholds, tpr, fpr
pd.DataFrame({'Threshold': thresholds, 
              'TPR': true_positive_rate, 
              'FPR':false_positive_rate
             })
# Out:
#         Threshold       TPR       FPR
# 0    2.000000e+00  0.000000  0.000000
# 1    1.000000e+00  0.308108  0.000000
# 2    1.000000e+00  0.313514  0.000000
# 3    1.000000e+00  0.335135  0.000000
# 4    1.000000e+00  0.340541  0.000000
# ..            ...       ...       ...
# 105  6.325596e-13  1.000000  0.959437
# 106  6.086604e-13  1.000000  0.961093
# 107  4.174215e-14  1.000000  0.970199
# 108  3.968331e-14  1.000000  0.972682
# 109  6.227131e-41  1.000000  1.000000
#
# [110 rows x 3 columns]

# %%
# plotting the ROC curve
# %matplotlib inline  
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC')
plt.plot(false_positive_rate, true_positive_rate)
